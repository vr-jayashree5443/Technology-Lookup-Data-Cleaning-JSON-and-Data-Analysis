# %% [markdown]
# dataset: https://raw.githubusercontent.com/sahilrahmann/Technology-Lookup-Web-Application/main/technologies.json
#
# JSON2(cats): https://raw.githubusercontent.com/chorsley/python-Wappalyzer/master/Wappalyzer/data/technologies.json

# %% [markdown]
# # Import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import re

# %%
df= pd.read_json("https://raw.githubusercontent.com/sahilrahmann/Technology-Lookup-Web-Application/main/technologies.json")

# %%
df1=df.copy()

# %%
df.head(2)
# Out:
#                                                      1C-Bitrix  3dCart  \
# cats                                                    [1, 6]  [1, 6]
# description  1C-Bitrix is a system of web project managemen...     NaN
#
#             @sulu/web A-Frame                                      A8.net  \
# cats             [59]    [25]                                        [71]
# description       NaN     NaN   A8.net is an affiliate marketing network.
#
#                                                       AB Tasty AD EBiS ADPLAN  \
# cats                                                      [74]    [10]   [10]
# description  AB Tasty is a customer experience optimization...     NaN    NaN
#
#                                                            AMP AMP Plugin  \
# cats                                                      [12]     [1, 5]
# description  AMP, originally created by Google, is an open-...        NaN
#
# ...

# %% [markdown]
# 1. Convert rows to columns, columns to rows
#
# (Transpose)

# %%
df1=df1.transpose()

# %%
df1.head(2)
# Out:
#              cats                                        description  \
# 1C-Bitrix  [1, 6]  1C-Bitrix is a system of web project managemen...
# 3dCart     [1, 6]                                                NaN
#
#                                                      headers  \
# 1C-Bitrix  {'Set-Cookie': 'BITRIX_', 'X-Powered-CMS': 'Bi...
# 3dCart                            {'X-Powered-By': '3DCART'}
#
#                                                         html           icon  \
# 1C-Bitrix  (?:<link[^>]+components/bitrix|(?:src|href)="/...  1C-Bitrix.svg
# 3dCart                                                   NaN     3dCart.png
#
#           implies                                scripts  \
# 1C-Bitrix     PHP                              1c-bitrix
# 3dCart        NaN  (?:twlh(?:track)?\.asp|3d_upsell\.js)
#
#                            website          cookies   js  ... pricing saas  \
# 1C-Bitrix  http://www.1c-bitrix.ru              NaN  NaN  ...     NaN  NaN
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1511 entries, 1C-Bitrix to xtCommerce
# Data columns (total 21 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   cats         1511 non-null   object
#  1   description  776 non-null    object
#  2   headers      320 non-null    object
#  3   html         428 non-null    object
#  4   icon         1474 non-null   object
#  5   implies      482 non-null    object
#  6   scripts      679 non-null    object
#  7   website      1511 non-null   object
#  8   cookies      146 non-null    object
#  9   js           600 non-null    object
#  10  dom          60 non-null     object
#  11  pricing      213 non-null    object
#  12  saas         204 non-null    object
#  13  meta         272 non-null    object
#  14  cpe          195 non-null    object
#  15  certIssuer   5 non-null      object
#  16  url          51 non-null     object
#  17  oss          31 non-null     object
# ...

# %%
# insights: 1. many null values
#           2. all datatypes not correct

# %%
df1.shape
# Out:
# (1511, 21)

# %%
# # if give a url: havt to scrap and find: what technology used
#based on: by refering and matiching the following parameters
#  1   description
#  2   headers
#  3   html
#  4   icon
#  5   implies
#  6   scripts
#  7   website
#  8   cookies
#  9   js
#  10  dom
#  11  pricing
#  12  saas
#  13  meta
#  14  cpe
#  15  certIssuer
#  16  url
#  17  oss
#  18  dns
#  19  excludes
#  20  css

# %% [markdown]
# --------------------------------------------------------------------
#
# PART-1 Cleaning
#
# ---------------------------------------------------------------------

# %% [markdown]
# 1. **cats:** column eg: [1,6]
#
# there is a 2nd JSON file
# it has: 1- what category
# 2- what category
#
# use that
# in this(present one) table- replace 1 by actual category, 16 by actual category

# %%
df_tech=df1.copy()
df_cats=pd.read_json("https://raw.githubusercontent.com/chorsley/python-Wappalyzer/master/Wappalyzer/data/technologies.json")
# Out:
# <ipython-input-25-cb9423f7342e>:2: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df_cats=pd.read_json("https://raw.githubusercontent.com/chorsley/python-Wappalyzer/master/Wappalyzer/data/technologies.json")
# <ipython-input-25-cb9423f7342e>:2: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df_cats=pd.read_json("https://raw.githubusercontent.com/chorsley/python-Wappalyzer/master/Wappalyzer/data/technologies.json")
# ...

# %%
df_cats.head()
# Out:
#           $schema                                    categories technologies
# 1  ../schema.json                {'name': 'CMS', 'priority': 1}          NaN
# 2  ../schema.json     {'name': 'Message boards', 'priority': 1}          NaN
# 3  ../schema.json  {'name': 'Database managers', 'priority': 2}          NaN
# 4  ../schema.json      {'name': 'Documentation', 'priority': 2}          NaN
# 5  ../schema.json            {'name': 'Widgets', 'priority': 9}          NaN

# %%
df_tech.head(3)
# Out:
#              cats                                        description  \
# 1C-Bitrix  [1, 6]  1C-Bitrix is a system of web project managemen...
# 3dCart     [1, 6]                                                NaN
# @sulu/web    [59]                                                NaN
#
#                                                      headers  \
# 1C-Bitrix  {'Set-Cookie': 'BITRIX_', 'X-Powered-CMS': 'Bi...
# 3dCart                            {'X-Powered-By': '3DCART'}
# @sulu/web                                                NaN
#
#                                                         html           icon  \
# 1C-Bitrix  (?:<link[^>]+components/bitrix|(?:src|href)="/...  1C-Bitrix.svg
# 3dCart                                                   NaN     3dCart.png
# @sulu/web                                                NaN       Sulu.svg
#
#           implies                                scripts  \
# 1C-Bitrix     PHP                              1c-bitrix
# ...

# %%
dict={}
for i in range(0,len(df_cats.categories.dropna())):
  dict[df]=df_cats.categories[i]['name']

# %%
new_cats=[]
for i in df_tech.cats:
  i=pd.Series(i)
  i=i.replace(dict)
  i=list(i)
  print(i)
  new_cats.append(i)
# Out:
# ['CMS', 'Ecommerce']
# ['CMS', 'Ecommerce']
# ['PaaS']
# ['JavaScript graphics']
# ['A/B Testing']
# [74]
# ['Analytics']
# ['Analytics']
# ['JavaScript frameworks']
# ['CMS', 'Widgets']
# ['Web servers']
# ['PaaS']
# ['Analytics']
# ['Analytics']
# ['Ecommerce']
# ['A/B Testing']
# ['Surveys']
# ['Analytics']
# ['Ecommerce']
# ['A/B Testing']
# ['Affiliate programs']
# ['Ecommerce', 'Email']
# ['Load balancers']
# ['Marketing automation']
# ['Advertising']
# ['Advertising']
# ['Advertising']
# ['Advertising']
# ['Affiliate programs']
# ['Advertising']
# ['Widgets', 'Analytics']
# ['Widgets']
# ['Widgets']
# ['Database managers']
# ['Advertising']
# ['Analytics']
# ['Web frameworks']
# ['CI']
# ['CMS']
# ['Analytics']
# ['CI']
# ['Editors']
# ['Documentation']
# ['Marketing automation', 74]
# ['Web frameworks']
# ['Analytics']
# ['Advertising']
# ['Advertising']
# ['Tag managers']
# ['Advertising']
# ['Blogs']
# ['A/B Testing', 'Advertising']
# ['A/B Testing']
# ['Ecommerce']
# ...

# %%
dict
# Out:
# {1: 'CMS',
#  2: 'Message boards',
#  3: 'Database managers',
#  4: 'Documentation',
#  5: 'Widgets',
#  6: 'Ecommerce',
#  7: 'Photo galleries',
#  8: 'Wikis',
#  9: 'Hosting panels',
#  10: 'Analytics',
#  11: 'Blogs',
#  12: 'JavaScript frameworks',
#  13: 'Issue trackers',
#  14: 'Video players',
#  15: 'Comment systems',
#  16: 'Security',
#  17: 'Font scripts',
#  18: 'Web frameworks',
#  19: 'Miscellaneous',
#  20: 'Editors',
#  21: 'LMS',
#  22: 'Web servers',
#  23: 'Caching',
#  24: 'Rich text editors',
#  25: 'JavaScript graphics',
#  26: 'Mobile frameworks',
#  27: 'Programming languages',
#  28: 'Operating systems',
#  29: 'Search engines',
#  30: 'Webmail',
#  31: 'CDN',
#  32: 'Marketing automation',
#  33: 'Web server extensions',
#  34: 'Databases',
#  35: 'Maps',
#  36: 'Advertising',
#  37: 'Network devices',
#  38: 'Media servers',
#  39: 'Webcams',
#  40: 'Payment processors',
#  41: 'Tag managers',
#  42: 'CI',
#  43: 'Control systems',
#  44: 'Remote access',
# ...

# %%
df_cats.index[70] # means lopp iterator i=70, but actual index is 74
# Out:
# '74'

# %%
len(df_cats.categories.dropna())
# Out:
# 72

# %%
###################startover

# %%
df_tech.head(2)
# Out:
#              cats                                        description  \
# 1C-Bitrix  [1, 6]  1C-Bitrix is a system of web project managemen...
# 3dCart     [1, 6]                                                NaN
#
#                                                      headers  \
# 1C-Bitrix  {'Set-Cookie': 'BITRIX_', 'X-Powered-CMS': 'Bi...
# 3dCart                            {'X-Powered-By': '3DCART'}
#
#                                                         html           icon  \
# 1C-Bitrix  (?:<link[^>]+components/bitrix|(?:src|href)="/...  1C-Bitrix.svg
# 3dCart                                                   NaN     3dCart.png
#
#           implies                                scripts  \
# 1C-Bitrix     PHP                              1c-bitrix
# 3dCart        NaN  (?:twlh(?:track)?\.asp|3d_upsell\.js)
#
#                            website          cookies   js  ... pricing saas  \
# 1C-Bitrix  http://www.1c-bitrix.ru              NaN  NaN  ...     NaN  NaN
# ...

# %%
df_cats.head()
# Out:
#           $schema                                    categories technologies
# 1  ../schema.json                {'name': 'CMS', 'priority': 1}          NaN
# 2  ../schema.json     {'name': 'Message boards', 'priority': 1}          NaN
# 3  ../schema.json  {'name': 'Database managers', 'priority': 2}          NaN
# 4  ../schema.json      {'name': 'Documentation', 'priority': 2}          NaN
# 5  ../schema.json            {'name': 'Widgets', 'priority': 9}          NaN

# %%
dict1={}
indices=df_cats.index
for i in range(0,len(df_cats.categories.dropna())):
  x=indices[i]
  # dict1[x]=2
  dict1[int(x)]=df_cats.categories[i]['name']

# %%
dict1
# Out:
# {1: 'CMS',
#  2: 'Message boards',
#  3: 'Database managers',
#  4: 'Documentation',
#  5: 'Widgets',
#  6: 'Ecommerce',
#  7: 'Photo galleries',
#  8: 'Wikis',
#  9: 'Hosting panels',
#  10: 'Analytics',
#  11: 'Blogs',
#  12: 'JavaScript frameworks',
#  13: 'Issue trackers',
#  14: 'Video players',
#  15: 'Comment systems',
#  16: 'Security',
#  17: 'Font scripts',
#  18: 'Web frameworks',
#  19: 'Miscellaneous',
#  20: 'Editors',
#  21: 'LMS',
#  22: 'Web servers',
#  23: 'Caching',
#  24: 'Rich text editors',
#  25: 'JavaScript graphics',
#  26: 'Mobile frameworks',
#  27: 'Programming languages',
#  28: 'Operating systems',
#  29: 'Search engines',
#  30: 'Webmail',
#  31: 'CDN',
#  32: 'Marketing automation',
#  33: 'Web server extensions',
#  34: 'Databases',
#  35: 'Maps',
#  36: 'Advertising',
#  37: 'Network devices',
#  38: 'Media servers',
#  39: 'Webcams',
#  41: 'Payment processors',
#  42: 'Tag managers',
#  44: 'CI',
#  45: 'Control systems',
#  46: 'Remote access',
# ...

# %%
###########good

# %%
new_cats=[]
for i in df_tech.cats:
  i=pd.Series(i)
  i=i.replace(dict1)
  i=list(i)
  print(i)
  new_cats.append(i)
# cant use replace function on a list,
# so, convert ti Series
# apply replace function
#convert back to list and put it
# Out:
# ['CMS', 'Ecommerce']
# ['CMS', 'Ecommerce']
# ['JavaScript libraries']
# ['JavaScript graphics']
# ['Affiliate programs']
# ['A/B Testing']
# ['Analytics']
# ['Analytics']
# ['JavaScript frameworks']
# ['CMS', 'Widgets']
# ['Web servers']
# ['JavaScript libraries']
# ['Analytics']
# ['Analytics']
# ['Ecommerce']
# ['Affiliate programs']
# ['SSL/TLS certificate authorities']
# ['Analytics']
# ['Ecommerce']
# ['Affiliate programs']
# ['Accessibility']
# ['Ecommerce', 'Appointment scheduling']
# ['PaaS']
# ['Marketing automation']
# ['Advertising']
# ['Advertising']
# ['Advertising']
# ['Advertising']
# ['Accessibility']
# ['Advertising']
# ['Widgets', 'Analytics']
# ['Widgets']
# ['Widgets']
# ['Database managers']
# ['Advertising']
# ['Analytics']
# ['Web frameworks']
# ['Tag managers']
# ['CMS']
# ['Analytics']
# ['Tag managers']
# ['Editors']
# ['Documentation']
# ['Marketing automation', 'A/B Testing']
# ['Web frameworks']
# ['Analytics']
# ['Advertising']
# ['Advertising']
# ...

# %%
df_tech.cats=new_cats

# %%
df_tech
# Out:
#                               cats  \
# 1C-Bitrix         [CMS, Ecommerce]
# 3dCart            [CMS, Ecommerce]
# @sulu/web   [JavaScript libraries]
# A-Frame      [JavaScript graphics]
# A8.net        [Affiliate programs]
# ...                            ...
# wisyCMS                      [CMS]
# wpBakery           [Page builders]
# wpCache                  [Caching]
# xCharts      [JavaScript graphics]
# xtCommerce             [Ecommerce]
#
#                                                   description  \
# 1C-Bitrix   1C-Bitrix is a system of web project managemen...
# 3dCart                                                    NaN
# @sulu/web                                                 NaN
# A-Frame                                                   NaN
# A8.net              A8.net is an affiliate marketing network.
# ...                                                       ...
# wisyCMS                                                   NaN
# ...

# %%
df_tech['cats']
# Out:
# 1C-Bitrix           [CMS, Ecommerce]
# 3dCart              [CMS, Ecommerce]
# @sulu/web     [JavaScript libraries]
# A-Frame        [JavaScript graphics]
# A8.net          [Affiliate programs]
#                        ...
# wisyCMS                        [CMS]
# wpBakery             [Page builders]
# wpCache                    [Caching]
# xCharts        [JavaScript graphics]
# xtCommerce               [Ecommerce]
# Name: cats, Length: 1511, dtype: object

# %% [markdown]
# 2. Descripition column

# %%
df_tech.description.isnull().sum()
# Out:
# 735

# %%
#df_tech[df_tech.description.isnull()==True] # but we will not drop(we need it)

# %% [markdown]
# 3. headers column

# %%
df_tech.headers[0]
# Out:
# {'Set-Cookie': 'BITRIX_', 'X-Powered-CMS': 'Bitrix Site Manager'}

# %%
df_tech.headers.isnull().sum()
# Out:
# 1191

# %%
df_tech.headers.notnull().sum()
# Out:
# 320

# %%
df_tech.headers[:5]
# Out:
# 1C-Bitrix    {'Set-Cookie': 'BITRIX_', 'X-Powered-CMS': 'Bi...
# 3dCart                              {'X-Powered-By': '3DCART'}
# @sulu/web                                                  NaN
# A-Frame                                                    NaN
# A8.net                                                     NaN
# Name: headers, dtype: object

# %%
# get unique keys
#Step1: iterate and get keys
#Step2: find unique among that

# %%
#Step1
head=[]
for i in df_tech.headers.dropna():#cant find keys for null values, so drop
  c=i.keys()
  head+=c
  print(list(c))
# Out:
# ['Set-Cookie', 'X-Powered-CMS']
# ['X-Powered-By']
# ['Server']
# ['X-AH-Environment']
# ['X-Advertising-By']
# ['Cookie']
# ['X-Powered-By']
# ['X-Powered-By']
# ['Server']
# ['X-Akamai-Transformed', 'X-EdgeConnect-MidMile-RTT', 'X-EdgeConnect-Origin-MEX-Latency']
# ['X-Akaunting']
# ['Server']
# ['Server']
# ['Via', 'X-Amz-Cf-Id']
# ['Server']
# ['Server']
# ['server']
# ['X-Powered-By']
# ['Server']
# ['Server', 'X-Powered-By']
# ['Server']
# ['X-Powered-By']
# ['Arastta', 'X-Arastta']
# ['Server']
# ['AR-PoweredBy']
# ['X-Confluence-Request-Time']
# ['X-StatusPage-Skip-Logging', 'X-StatusPage-Version']
# ['X-Hacker']
# ['Server']
# ['azure-regionname', 'azure-sitename', 'azure-slotname', 'azure-version']
# ['X-EC-Debug', 'server']
# ['X-Supplied-By']
# ['X-Backdrop-Cache', 'X-Generator']
# ['X-Powered-By']
# ['CMS-Version']
# ['X-Powered-By']
# ['x-bubble-capacity-limit', 'x-bubble-capacity-used', 'x-bubble-perf']
# ['Server']
# ['X-Powered-By']
# ['Server', 'X-CF1', 'X-CF2']
# ...

# %%
pd.Series(head).unique()
# Out:
# array(['Set-Cookie', 'X-Powered-CMS', 'X-Powered-By', 'Server',
#        'X-AH-Environment', 'X-Advertising-By', 'Cookie',
#        'X-Akamai-Transformed', 'X-EdgeConnect-MidMile-RTT',
#        'X-EdgeConnect-Origin-MEX-Latency', 'X-Akaunting', 'Via',
#        'X-Amz-Cf-Id', 'server', 'Arastta', 'X-Arastta', 'AR-PoweredBy',
#        'X-Confluence-Request-Time', 'X-StatusPage-Skip-Logging',
#        'X-StatusPage-Version', 'X-Hacker', 'azure-regionname',
#        'azure-sitename', 'azure-slotname', 'azure-version', 'X-EC-Debug',
#        'X-Supplied-By', 'X-Backdrop-Cache', 'X-Generator', 'CMS-Version',
#        'x-bubble-capacity-limit', 'x-bubble-capacity-used',
#        'x-bubble-perf', 'X-CF1', 'X-CF2', 'X-Plenty-Shop',
#        'Access-Control-Allow-Headers', 'Link', 'cf-cache-status',
#        'cf-ray', 'COMMERCE-SERVER-SOFTWARE', 'Derak-Umbrage',
#        'DNNOutputCache', 'X-Compressed-By', 'X-DataDome',
#        'X-DataDome-CID', 'X-Dotclear-Static-Cache', 'Expires',
# ...

# %%
unique_headers_keys=pd.Series(head).unique()
len(unique_headers_keys)
# Out:
# 185

# %%
# c={'X-Powered-By': '^Strapi'}.keys()
# .key xx
# .keys() correct

# %%
c
# Out:
# dict_keys(['X-Powered-By'])

# %% [markdown]
# -------------------------------------------------------------
# PART-2 Lookup System
#
# -----------------------------------------------------------------

# %% [markdown]
# write re for input url
#
# sample input:amazon.in/s?k=laptop&crid=1MC90KDBU4DI9&sprefix=lapto%2Caps%2C276&ref=nb_sb_noss_2
#
# output:  https://amazon.in

# %%
#motive: extract domain name
i="amazon.in/s?k=laptop&crid=1MC90KDBU4DI9&sprefix=lapto%2Caps%2C276&ref=nb_sb_noss_2"

# %%
re.sub("/.*","",str(i))
# Out:
# 'amazon.in'

# %%
i="www.amazon.in/s?k=laptop&crid=1MC90KDBU4DI9&sprefix=lapto%2Caps%2C276&ref=nb_sb_noss_2"

# %%
re.sub("/.*|www.","",str(i))
# Out:
# 'amazon.in'

# %%
# try other links

# %%
i="https://drive.google.com/drive/folders/1vaofmc-gprJzLcyWy7ohPMJmQkHdq2a4"

# %%
re.sub(".*//|/.*|www.","",str(i))
# Out:
# 'drive.google.com'

# %%
i="https://github.com/mkartik/EDA_4chan/blob/master/technology.json"

# %%
re.sub(".*//|/.*|www.","",str(i))
# Out:
# 'github.com'

# %%
i="https://www.google.com/search?q=custom+intervalized+histogram+in+matplotlib&sca_esv=4188d43fabe6cc89&sca_upv=1&rlz=1C1RXQR_enIN1091IN1092&sxsrf=ACQVn0-ncGVshoKnRWhnkMY-LQ4acglRAQ%3A1712797669259&ei=5TcXZqa1D_nD4-EP6O-kuA8&ved=0ahUKEwjmu5fF_LiFAxX54TgGHeg3CfcQ4dUDCBA&uact=5&oq=custom+intervalized+histogram+in+matplotlib&gs_lp=&sclient=gws-wiz-serp"

# %%
re.sub(".*//|/.*|www.","",str(i))
# Out:
# 'google.com'

# %%
output="https://"+re.sub(".*//|/.*|www.","",str(i))

# %%
output
# Out:
# 'https://google.com'

# %%
i="https://en.wikipedia.org/wiki/Avengers:_Endgame"

# %%
re.sub("//[\w]*[\.]","",str(i))
# Out:
# 'https:wikipedia.org/wiki/Avengers:_Endgame'

# %%
###############revised
re.sub(".*//[\w]*.|.*//|www.|/.*","",str(i))
# Out:
# 'wikipedia.org'

# %%
output="https://"+re.sub(".*//[a-z]*.|.*//|www.|/.*","",str(i))

# %%
output
# Out:
# 'https://wikipedia.org'

# %% [markdown]
# 2. get input url, scrap

# %%
url="https://www.amazon.in/s?k=laptop&crid=1MC90KDBU4DI9&sprefix=lapto%2Caps%2C276&ref=nb_sb_noss_2"
_url="https://"+re.sub(".*//[a-z]*.|.*//|www.|/.*","",str(url))

# %%
from bs4 import BeautifulSoup
import requests

req=requests.get(_url)
_url
# Out:
# 'https://amazon.in'

# %%
req # good to go
# Out:
# <Response [200]>

# %%
soup =BeautifulSoup(req.content)

# %%
soup
# Out:
# <!DOCTYPE html>
# <!--[if lt IE 7]> <html lang="en-us" class="a-no-js a-lt-ie9 a-lt-ie8 a-lt-ie7"> <![endif]--><!--[if IE 7]>    <html lang="en-us" class="a-no-js a-lt-ie9 a-lt-ie8"> <![endif]--><!--[if IE 8]>    <html lang="en-us" class="a-no-js a-lt-ie9"> <![endif]--><!--[if gt IE 8]><!--><html class="a-no-js" lang="en-us"><!--<![endif]--><head>
# <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
# <meta charset="utf-8"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <title dir="ltr">Amazon.in</title>
# <meta content="width=device-width" name="viewport"/>
# <link href="https://images-na.ssl-images-amazon.com/images/G/01/AUIClients/AmazonUI-3c913031596ca78a3768f4e934b1cc02ce238101.secure.min._V1_.css" rel="stylesheet"/>
# <script>
#
# if (true === true) {
#     var ue_t0 = (+ new Date()),
#         ue_csm = window,
#         ue = { t0: ue_t0, d: function() { return (+new Date() - ue_t0); } },
#         ue_furl = "fls-eu.amazon.in",
# ...

# %% [markdown]
# 3. Find the technology

# %%
req.headers
# Out:
# {'Content-Type': 'text/html', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'Server': 'Server', 'Date': 'Thu, 11 Apr 2024 05:36:01 GMT', 'x-amz-rid': '992KTJ2VYBYCM68WT97M', 'Vary': 'Content-Type,Accept-Encoding,User-Agent', 'Content-Encoding': 'gzip', 'Cache-Control': 'no-transform', 'Strict-Transport-Security': 'max-age=47474747; includeSubDomains; preload', 'X-Cache': 'Error from cloudfront', 'Via': '1.1 d419ac9a83ef724c262c5f07f9b5a8da.cloudfront.net (CloudFront)', 'X-Amz-Cf-Pop': 'AMS58-P4', 'Alt-Svc': 'h3=":443"; ma=86400', 'X-Amz-Cf-Id': '0bRTzY9q9BgQgR-rrS427utBn0bNVA7yvSOO33XnnxaHiOOhTj2jtg=='}

# %%
req.cookies.get_dict().keys()
# Out:
# dict_keys([])

# %%
df_tech.iloc[0:2]
# Out:
#                        cats  \
# 1C-Bitrix  [CMS, Ecommerce]
# 3dCart     [CMS, Ecommerce]
#
#                                                  description  \
# 1C-Bitrix  1C-Bitrix is a system of web project managemen...
# 3dCart                                                   NaN
#
#                                                      headers  \
# 1C-Bitrix  {'Set-Cookie': 'BITRIX_', 'X-Powered-CMS': 'Bi...
# 3dCart                            {'X-Powered-By': '3DCART'}
#
#                                                         html           icon  \
# 1C-Bitrix  (?:<link[^>]+components/bitrix|(?:src|href)="/...  1C-Bitrix.svg
# 3dCart                                                   NaN     3dCart.png
#
#           implies                                scripts  \
# 1C-Bitrix     PHP                              1c-bitrix
# 3dCart        NaN  (?:twlh(?:track)?\.asp|3d_upsell\.js)
#
#                            website          cookies   js  ... pricing saas  \
# ...

# %%
for i in df_tech.columns:
  print(i)
# Out:
# cats
# description
# headers
# html
# icon
# implies
# scripts
# website
# cookies
# js
# dom
# pricing
# saas
# meta
# cpe
# certIssuer
# url
# oss
# dns
# excludes
# css

# %%
len(df_tech)
# Out:
# 1511

# %%
df_tech.cats[0:2]
# Out:
# 1C-Bitrix    [CMS, Ecommerce]
# 3dCart       [CMS, Ecommerce]
# Name: cats, dtype: object

# %%
df_tech.cats.notnull().sum()
# Out:
# 1511

# %%
df_tech.description[0:2]
# Out:
# 1C-Bitrix    1C-Bitrix is a system of web project managemen...
# 3dCart                                                     NaN
# Name: description, dtype: object

# %%
df_tech.description.notnull().sum()
# Out:
# 776

# %%
df_tech.headers[0:2]
# Out:
# 1C-Bitrix    {'Set-Cookie': 'BITRIX_', 'X-Powered-CMS': 'Bi...
# 3dCart                              {'X-Powered-By': '3DCART'}
# Name: headers, dtype: object

# %%
df_tech.headers.notnull().sum()
# Out:
# 320

# %%
df_tech.html[0:2]
# Out:
# 1C-Bitrix    (?:<link[^>]+components/bitrix|(?:src|href)="/...
# 3dCart                                                     NaN
# Name: html, dtype: object

# %%
df_tech.html.notnull().sum()
# Out:
# 428

# %%
df_tech.icon[0:2]
# Out:
# 1C-Bitrix    1C-Bitrix.svg
# 3dCart          3dCart.png
# Name: icon, dtype: object

# %%
df_tech.icon.notnull().sum()
# Out:
# 1474

# %%
df_tech.implies[0:2]
# Out:
# 1C-Bitrix    PHP
# 3dCart       NaN
# Name: implies, dtype: object

# %%
df_tech.implies.notnull().sum()
# Out:
# 482

# %%
df_tech.scripts[0:2]
# Out:
# 1C-Bitrix                                1c-bitrix
# 3dCart       (?:twlh(?:track)?\.asp|3d_upsell\.js)
# Name: scripts, dtype: object

# %%
df_tech.scripts.notnull().sum()
# Out:
# 679

# %%
df_tech.website[0:2]
# Out:
# 1C-Bitrix    http://www.1c-bitrix.ru
# 3dCart         http://www.3dcart.com
# Name: website, dtype: object

# %%
df_tech.website.notnull().sum()
# Out:
# 1511

# %%
df_tech[df_tech.cookies.isnull()==False]['cookies'].head(3)
# Out:
# 3dCart                                        {'3dvisit': ''}
# AWIN                           {'BAGawin': '', '_aw_xid': ''}
# AdonisJS    {'adonis-session': '', 'adonis-session-values'...
# Name: cookies, dtype: object

# %%
df_tech.cookies.notnull().sum()
# Out:
# 146

# %%
df_tech[df_tech.js.isnull()==False]['js'].head(3)
# Out:
# @sulu/web                          {'web.startComponents': ''}
# A-Frame               {'AFRAME.version': '^(.+)$\;version:\1'}
# A8.net       {'A8salesCookieRepository': '', 'a8sales': '',...
# Name: js, dtype: object

# %%
df_tech.js.notnull().sum()
# Out:
# 600

# %%
df_tech[df_tech.dom.isnull()==False]['dom'].head(3)
# Out:
# A8.net         {'img[src*='.a8.net']': {'attributes': {'src':...
# ATSHOP         {'link[href*='cdn\.atshop\.io']': {'attributes...
# AccessTrade    {'img[src*='.accesstrade.net'],img[data-src*='...
# Name: dom, dtype: object

# %%
df_tech.dom.notnull().sum()
# Out:
# 60

# %%
df_tech[df_tech.pricing.isnull()==False]['pricing'].head(3)
# Out:
# AB Tasty               [poa]
# ATSHOP      [low, recurring]
# AWIN                  [payg]
# Name: pricing, dtype: object

# %%
df_tech.pricing.notnull().sum()
# Out:
# 213

# %%
df_tech[df_tech.saas.isnull()==False]['saas'].head(3)
# Out:
# AB Tasty    True
# ATSHOP      True
# AWIN        True
# Name: saas, dtype: object

# %%
df_tech.saas.notnull().sum()
# Out:
# 204

# %%
df_tech[df_tech.meta.isnull()==False]['meta'].head(3)
# Out:
# AMP Plugin    {'generator': '^AMP Plugin v(\d+\.\d+.*)$\;ver...
# AWStats       {'generator': 'AWStats ([\d.]+(?: \(build [\d....
# Abicart           {'generator': ['Abicart', 'Textalk Webshop']}
# Name: meta, dtype: object

# %%
df_tech.meta.notnull().sum()
# Out:
# 272

# %%
df_tech[df_tech.cpe.isnull()==False]['cpe'].head(3)
# Out:
# AOLserver                         cpe:/a:aol:aolserver
# AWStats             cpe:/a:laurent_destailleur:awstats
# Adobe ColdFusion               cpe:/a:adobe:coldfusion
# Name: cpe, dtype: object

# %%
df_tech.cpe.notnull().sum()
# Out:
# 195

# %%
df_tech[df_tech.certIssuer.isnull()==False]['certIssuer'].head(3)
# Out:
# AWS Certificate Manager      Amazon
# DigiCert                   DigiCert
# Identrust                   TrustID
# Name: certIssuer, dtype: object

# %%
df_tech.certIssuer.notnull().sum()
# Out:
# 5

# %%
df_tech[df_tech.url.isnull()==False]['url'].head(3)
# Out:
# Adcash              ^https?://(?:[^\/]+\.)?adcash\.com/script/pop_
# Adobe ColdFusion                                     \.cfm(?:$|\?)
# Apache JSPWiki                                           wiki\.jsp
# Name: url, dtype: object

# %%
df_tech.url.notnull().sum()
# Out:
# 51

# %%
df_tech[df_tech.oss.isnull()==False]['oss'].head(3)
# Out:
# Akaunting    True
# Boomerang    True
# Contao       True
# Name: oss, dtype: object

# %%
df_tech.oss.notnull().sum()
# Out:
# 31

# %%
df_tech[df_tech.dns.isnull()==False]['dns'].head(3)
# Out:
# Amazon Cloudfront      {'CNAME': '^[a-z0-9]+\.cloudfront.net\.?$'}
# Amazon SES                             {'TXT': ['amazonses\.com']}
# Amazon Web Services                            {'NS': '\.awsdns-'}
# Name: dns, dtype: object

# %%
df_tech.dns.notnull().sum()
# Out:
# 23

# %%
df_tech[df_tech.excludes.isnull()==False]['excludes'].head(3)
# Out:
# Angular        [AngularDart, AngularJS]
# AngularDart        [Angular, AngularJS]
# AngularJS        [Angular, AngularDart]
# Name: excludes, dtype: object

# %%
df_tech.excludes.notnull().sum()
# Out:
# 21

# %%
df_tech[df_tech.css.isnull()==False]['css'].head(3)
# Out:
# Smartstore Page Builder      \.g-stage \.g-stage-root
# Vuetify                    \.v-application \.d-block
# Name: css, dtype: object

# %%
df_tech.css.notnull().sum()
# Out:
# 2

# %%
df_tech.columns
# Out:
# Index(['cats', 'description', 'headers', 'html', 'icon', 'implies', 'scripts',
#        'website', 'cookies', 'js', 'dom', 'pricing', 'saas', 'meta', 'cpe',
#        'certIssuer', 'url', 'oss', 'dns', 'excludes', 'css'],
#       dtype='object')

# %% [markdown]
# +++++++++++++++++++++++++++++++++++++++++++++++++

# %%
#STEP 1: Search in this
req.headers
# Out:
# {'Content-Type': 'text/html', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'Server': 'Server', 'Date': 'Thu, 11 Apr 2024 05:36:01 GMT', 'x-amz-rid': '992KTJ2VYBYCM68WT97M', 'Vary': 'Content-Type,Accept-Encoding,User-Agent', 'Content-Encoding': 'gzip', 'Cache-Control': 'no-transform', 'Strict-Transport-Security': 'max-age=47474747; includeSubDomains; preload', 'X-Cache': 'Error from cloudfront', 'Via': '1.1 d419ac9a83ef724c262c5f07f9b5a8da.cloudfront.net (CloudFront)', 'X-Amz-Cf-Pop': 'AMS58-P4', 'Alt-Svc': 'h3=":443"; ma=86400', 'X-Amz-Cf-Id': '0bRTzY9q9BgQgR-rrS427utBn0bNVA7yvSOO33XnnxaHiOOhTj2jtg=='}

# %%
#STEP 2: Search in this
req.cookies.get_dict().keys()
# Out:
# dict_keys([])

# %%
#STEP 3: Search in this
soup
# Out:
# <!DOCTYPE html>
# <!--[if lt IE 7]> <html lang="en-us" class="a-no-js a-lt-ie9 a-lt-ie8 a-lt-ie7"> <![endif]--><!--[if IE 7]>    <html lang="en-us" class="a-no-js a-lt-ie9 a-lt-ie8"> <![endif]--><!--[if IE 8]>    <html lang="en-us" class="a-no-js a-lt-ie9"> <![endif]--><!--[if gt IE 8]><!--><html class="a-no-js" lang="en-us"><!--<![endif]--><head>
# <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
# <meta charset="utf-8"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <title dir="ltr">Amazon.in</title>
# <meta content="width=device-width" name="viewport"/>
# <link href="https://images-na.ssl-images-amazon.com/images/G/01/AUIClients/AmazonUI-3c913031596ca78a3768f4e934b1cc02ce238101.secure.min._V1_.css" rel="stylesheet"/>
# <script>
#
# if (true === true) {
#     var ue_t0 = (+ new Date()),
#         ue_csm = window,
#         ue = { t0: ue_t0, d: function() { return (+new Date() - ue_t0); } },
#         ue_furl = "fls-eu.amazon.in",
# ...

# %%
req
# Out:
# <Response [503]>

# %%
#Technology
Tech=df_tech.index

# %%
#checkinh headers
for i in range(len(df_tech.headers)):
  if pd.Series(df_tech.headers[i]).isna().sum()==0:
    ke_dict=df_tech.headers[i]
    ke_list=list(df_tech.headers[i].keys())
    for h in range(0,len(list(df_tech.headers[i].keys()))):
      ke=str(ke_list[h])
      if ke in req.headers.keys():
        if req.headers[ke]==ke_dict[ke]:
          print("yes")

# %%
#checkinh cats
for i in df_tech.cats:
  for x in i:
    # if(soup.find(str(x))):
    #   print("Yes")
    count=0
    if x in str(req.headers):
      count+=1
    if count==len(x):
      print("Yes")

# %%
# check in df_tech.certIssuer
for i in df_tech.certIssuer:
  if i in df_tech.certIssuer.dropna():
    print(i)
    if(soup.find(str(i))):
      print(i)
# Out:
# DigiCert
# Let's Encrypt
# Sectigo

# %%
x=
# Out:
# Yes

# %%
findi=req.headers

# %%
for i in findi:
  print(i.values())

# %%
str(req.headers)
# Out:
# '{\'Content-Type\': \'text/html\', \'Transfer-Encoding\': \'chunked\', \'Connection\': \'keep-alive\', \'Server\': \'Server\', \'Date\': \'Thu, 11 Apr 2024 05:36:01 GMT\', \'x-amz-rid\': \'992KTJ2VYBYCM68WT97M\', \'Vary\': \'Content-Type,Accept-Encoding,User-Agent\', \'Content-Encoding\': \'gzip\', \'Cache-Control\': \'no-transform\', \'Strict-Transport-Security\': \'max-age=47474747; includeSubDomains; preload\', \'X-Cache\': \'Error from cloudfront\', \'Via\': \'1.1 d419ac9a83ef724c262c5f07f9b5a8da.cloudfront.net (CloudFront)\', \'X-Amz-Cf-Pop\': \'AMS58-P4\', \'Alt-Svc\': \'h3=":443"; ma=86400\', \'X-Amz-Cf-Id\': \'0bRTzY9q9BgQgR-rrS427utBn0bNVA7yvSOO33XnnxaHiOOhTj2jtg==\'}'

# %%
'Set-Cookie' in req.headers.keys()
# Out:
# True

# %%
soup=BeautifulSoup(req.content,'html.parser')

# %%
a= str(soup)

# %%
str([j[0] for (i, j) in zip(df_tech.columns, df_tech.iloc[:7]) if ((i or j) in a)])
# Out:
# "['h', 'i', 'c', 'j', 'm', 'u', 'c']"

# %%
df_tech.columns
# Out:
# Index(['cats', 'description', 'headers', 'html', 'icon', 'implies', 'scripts',
#        'website', 'cookies', 'js', 'dom', 'pricing', 'saas', 'meta', 'cpe',
#        'certIssuer', 'url', 'oss', 'dns', 'excludes', 'css'],
#       dtype='object')

# %%
i1=0
techs_used=[]
for i in df_tech.columns:

  for j in range(0,len(df_tech)):
    try:
      if(df_tech.iloc[j][i1] in a):
        techs_used.append(df_tech.index[j])
    except:
      pass
  i1+=1
print(techs_used)
# Out:
# ['Azion', 'AWS Certificate Manager']

# %%
df_tech.iloc[140].index
# Out:
# Index(['cats', 'description', 'headers', 'html', 'icon', 'implies', 'scripts',
#        'website', 'cookies', 'js', 'dom', 'pricing', 'saas', 'meta', 'cpe',
#        'certIssuer', 'url', 'oss', 'dns', 'excludes', 'css'],
#       dtype='object')

# %%
df_tech.index
# Out:
# Index(['1C-Bitrix', '3dCart', '@sulu/web', 'A-Frame', 'A8.net', 'AB Tasty',
#        'AD EBiS', 'ADPLAN', 'AMP', 'AMP Plugin',
#        ...
#        'user.com', 'vBulletin', 'vibecommerce', 'webEdition', 'webpack',
#        'wisyCMS', 'wpBakery', 'wpCache', 'xCharts', 'xtCommerce'],
#       dtype='object', length=1511)

# %%
df_tech.columns
# Out:
# Index(['cats', 'description', 'headers', 'html', 'icon', 'implies', 'scripts',
#        'website', 'cookies', 'js', 'dom', 'pricing', 'saas', 'meta', 'cpe',
#        'certIssuer', 'url', 'oss', 'dns', 'excludes', 'css'],
#       dtype='object')

# %%
df_tech.index[140]
# Out:
# 'Azion'

# %%
df_tech.index[6]
# Out:
# 'AD EBiS'

# %%
url="https://www.amazon.in/s?k=laptop&crid=1MC90KDBU4DI9&sprefix=lapto%2Caps%2C276&ref=nb_sb_noss_2"
_url="https://"+re.sub(".*//[a-z]*.|.*//|www.|/.*","",str(url))

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

req=requests.get(_url)
soup =BeautifulSoup(req.content)
a=str(soup)

# %%
i1=0
techs_used=[]
for i in df_tech.columns:

  for j in range(0,len(df_tech)):
    try:
      if(df_tech.iloc[j][i1] in a):
        techs_used.append(df_tech.index[j])
    except:
      pass
  i1+=1
print(techs_used)
# Out:
# ['Azion', 'AWS Certificate Manager']

# %%
df_tech.to_csv("d.csv")

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

def Technology():
  url=input()
  _url="https://"+re.sub(".*//[a-z]*.|.*//|www.|/.*","",str(url))
  req=requests.get(_url)
  soup =BeautifulSoup(req.content)
  a=str(soup)
  i1=0
  techs_used=[]
  for i in df_tech.columns:

    for j in range(0,len(df_tech)):
      try:
        if(df_tech.iloc[j][i1] in a):
          techs_used.append(df_tech.index[j])
      except:
        pass
    i1+=1
  return techs_used

ans=Technology()
print(ans)
# Out:
# https://www.google.com/search?q=replace+in+series+with+dict&sca_esv=e2291660b3e8fe71&sca_upv=1&rlz=1C1RXQR_enIN1091IN1092&sxsrf=ACQVn09zyUGkgHpujl-Sn0RLmwsLuyz0aA%3A1712805071972&ei=z1QXZpH-OvL24-EPwf2v0As&ved=0ahUKEwjRoYmPmLmFAxVy-zgGHcH-C7oQ4dUDCBA&uact=5&oq=replace+in+series+with+dict&gs_lp=Egxnd3Mtd2l6LXNlcnAiG3JlcGxhY2UgaW4gc2VyaWVzIHdpdGggZGljdDIGEAAYFhgeMgsQABiABBiKBRiGA0jyH1CYCFijHXABeACQAQCYAeIBoAGZEKoBBTAuNy40uAEDyAEA-AEBmAILoAKiD8ICChAAGEcY1gQYsAPCAgUQABiABMICBRAhGKABwgIFECEYnwXCAgcQIRgKGKABmAMAiAYBkAYIkgcFMS42LjSgB6hG&sclient=gws-wiz-serp
# ['Azion', 'Caddy', 'Revel']
